# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

x=np.array([-3., -1., 0.5, 2.5])
y=np.array([-8., 30., -8., 40.])

def lagrange_interpolation(x, y, x_pidst):
    n = len(x)
    m = np.zeros(n)
    for i in range(n):
        m_i = 1
        for j in range(n):
            if i != j:
                m_i *= (x_pidst - x[j])/(x[i] - x[j])
        m[i] = m_i
    return np.dot(y, m)

f_interp = lagrange_interpolation(x, y, -3)
print("Значення функції у точці x_test =", f_interp.round(4))
f_interp = lagrange_interpolation(x, y, -1)
print("Значення функції у точці x_test =", f_interp.round(4))
f_interp = lagrange_interpolation(x, y, 0.5)
print("Значення функції у точці x_test =", f_interp.round(4))
f_interp = lagrange_interpolation(x, y, 2.5)
print("Значення функції у точці x_test =", f_interp.round(4))

# Графік

xnew=np.linspace(np.min(x),np.max(x),100)
ynew=[lagrange_interpolation(x,y,i) for i in xnew]

plt.plot(x,y, 'o', xnew, ynew, 'g')
plt.title('Поліном Лагранжа №1')
plt.grid(True)
plt.xlabel('Вісь x')
plt.ylabel('Вісь y')
plt.show()

#Перевірка

f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), '#FFDD44', x, y, 'o')
plt.title('Поліном Лагранжа №2')
plt.grid()
plt.xlabel('Вісь x')
plt.ylabel('Вісь y')
plt.show()
# Out:
# Значення функції у точці x_test = -8.0
# Значення функції у точці x_test = 30.0
# Значення функції у точці x_test = -8.0
# Значення функції у точці x_test = 40.0
